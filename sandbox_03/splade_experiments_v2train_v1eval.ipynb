# %% [markdown]
# # SPLADE: side-experiment — v2 full train, v1 только eval
#
# Отдельный блокнот рядом с основным `splade_experiments.ipynb`. Отличие одно:
# **этап train для v1 исключён** — для v1 берётся уже обученная (последняя) модель
# из `outputs/v1_splade_max/` и прогоняется только инференс/eval. v2 прогоняется
# полностью (train + eval), как в основном блокноте.
#
# Чтобы не трогать `splade_lab/` и не сломать поведение основного блокнота, вся
# новая логика (eval-only без train) вынесена **прямо в этот блокнот** — это
# side-experiment. Используются только готовые кирпичики из `splade_lab` (модель,
# данные, eval, артефакты) без их изменения.
#
# Порядок:
# 1. **Setup** — окружение и устройство.
# 2. **Конфиг данных** — `MODE = "full"` и источники MS MARCO.
# 3. **Конфиг эксперимента** — только v2 (v1 не обучается).
# 4. **Данные** — переиспользуются (скачаны основным блокнотом).
# 5. **v1 eval-only** — последняя модель из `outputs/v1_splade_max/` -> eval.
# 6. **v2 full** — обучение + eval.
# 7. **Сравнение** — сводная таблица метрик всех прогонов.

# %% [markdown]
# ## 1. Setup

# %%
print("WORKS")
# Out:
# WORKS

# %%
# Первый запуск на новой машине (в активированном venv) — раскомментировать:
# %pip install -r requirements.txt
# %load_ext autoreload
# %autoreload 2

import json
import torch

from splade_lab.config import merge_config
from splade_lab.train import pick_device

device = pick_device()
print(f"torch {torch.__version__} | устройство: {device}"
      + (f" ({torch.cuda.get_device_name(0)})" if device.type == "cuda" else ""))
# Out:
# Looking in indexes: https://pypi.yandex-team.ru/simple/
# Requirement already satisfied: torch==2.5.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.5.1)
# Requirement already satisfied: transformers==4.46.3 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (4.46.3)
# Requirement already satisfied: numpy==1.26.4 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: scipy==1.13.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: pandas==2.2.3 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: tqdm==4.66.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (4.66.5)
# Requirement already satisfied: requests==2.32.3 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: ipykernel==6.29.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (6.29.5)
# Requirement already satisfied: ipywidgets==8.1.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (8.1.5)
# Requirement already satisfied: jupyterlab==4.3.4 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (4.3.4)
# Requirement already satisfied: filelock in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: networkx in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from transformers==4.46.3->-r requirements.txt (line 2)) (0.36.2)
# Requirement already satisfied: packaging>=20.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from transformers==4.46.3->-r requirements.txt (line 2)) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from transformers==4.46.3->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from transformers==4.46.3->-r requirements.txt (line 2)) (2026.5.9)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from transformers==4.46.3->-r requirements.txt (line 2)) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from transformers==4.46.3->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r requirements.txt (line 5)) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r requirements.txt (line 5)) (2026.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from requests==2.32.3->-r requirements.txt (line 7)) (2026.5.20)
# Requirement already satisfied: comm>=0.1.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (9.14.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: nest-asyncio in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: psutil in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (7.2.2)
# Requirement already satisfied: pyzmq>=24 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (27.1.0)
# Requirement already satisfied: tornado>=6.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (6.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 8)) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipywidgets==8.1.5->-r requirements.txt (line 9)) (4.0.15)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipywidgets==8.1.5->-r requirements.txt (line 9)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: httpx>=0.25.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.19.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab==4.3.4->-r requirements.txt (line 10)) (79.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from sympy==1.13.1->torch==2.5.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.3->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.4->-r requirements.txt (line 10)) (4.24.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: httpcore==1.* in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: decorator>=5.1.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jinja2->torch==2.5.1->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.4->-r requirements.txt (line 10)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.4->-r requirements.txt (line 10)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.4->-r requirements.txt (line 10)) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.29.5->-r requirements.txt (line 8)) (4.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.1.1)
# Requirement already satisfied: fqdn in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: isoduration in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (3.1.1)
# Requirement already satisfied: uri-template in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (6.3.0)
# Requirement already satisfied: defusedxml in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: webencodings in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 8)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: pycparser in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in /home/uvuv/workspace/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.4->-r requirements.txt (line 10)) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.
# torch 2.5.1+cu124 | устройство: cuda (NVIDIA A100 80GB PCIe)

# %% [markdown]
# ## 2. Конфиг данных
#
# Те же данные, что и в основном блокноте (`full` — коллекция 8.8M пассажей + dev small).
# Если основной блокнот уже подготовил `data/msmarco/full`, повторное скачивание не нужно.

# %%
MODE = "full"  # side-experiment по умолчанию в full (v1 берётся из готовых outputs)

DATA = {
    # Официальные файлы Microsoft. Если хост недоступен — зеркало:
    # https://msmarco.blob.core.windows.net/msmarcoranking/
    "urls": {
        "triples": "https://msmarco.z22.web.core.windows.net/msmarcoranking/triples.train.small.tar.gz",
        "collection": "https://msmarco.z22.web.core.windows.net/msmarcoranking/collection.tar.gz",
        "queries": "https://msmarco.z22.web.core.windows.net/msmarcoranking/queries.tar.gz",
        "qrels_dev": "https://msmarco.z22.web.core.windows.net/msmarcoranking/qrels.dev.small.tsv",
    },
    "data_dir": "data/msmarco",  # относительно корня репозитория
    "smoke": {
        "num_train_triples": 256,  # строк triples на обучение
        "num_eval_queries": 20,    # уникальных eval-запросов (не пересекаются с train)
        "num_corpus_docs": 1000,   # корпус: positives eval-запросов + дистракторы
    },
    "full": {
        "num_train_triples": 3_200_000,  # ~ max_steps * batch_size; -1 = весь файл (39.8M строк)
        "num_eval_queries": -1,          # -1 = все 6980 запросов dev small
    },
}

print(f"MODE = {MODE} | параметры данных: {DATA[MODE]}")
# Out:
# MODE = full | параметры данных: {'num_train_triples': 3200000, 'num_eval_queries': -1}

# %% [markdown]
# ## 3. Конфиг эксперимента (только v2)
#
# Здесь обучается **только v2_splade_doc** (SPLADE-doc). v1 не обучается — его веса
# берутся готовыми из `outputs/v1_splade_max/` на этапе eval (клетка 5).
#
# `BASE`/`SMOKE_OVERRIDES`/`build_config` совпадают с основным блокнотом, чтобы
# конфиг v2 был идентичен.

# %%
# База: гиперпараметры статьи (distilbert, Adam 2e-5, warmup 6000, max_len 256).
BASE = {
    "model": {
        "hf_model": "distilbert-base-uncased",
        "query_encoder": "mlm",      # mlm = SPLADE-max | bow = SPLADE-doc
        "max_len_query": 32,
        "max_len_doc": 256,
    },
    "train": {
        "seed": 4,
        "lr": 2e-5,
        "batch_size": 64,
        "max_steps": 100_000,
        "warmup_steps": 6_000,
        "flops_warmup_steps": 10_000,  # квадратичный разгон лямбд (SPLADE v2)
        "lambda_q": 3e-4,              # FLOPS-рег. запросов
        "lambda_d": 1e-4,              # FLOPS-рег. документов
        "log_every": 100,
    },
    "eval": {
        "batch_size_docs": 256,
        "batch_size_queries": 64,
        "batch_size_search": 64,
        "recall_ks": [10, 100, 1000],
    },
}

# Smoke: всё маленькое, схема артефактов та же.
SMOKE_OVERRIDES = {
    "model": {"max_len_doc": 128},
    "train": {"max_steps": 20, "batch_size": 8, "warmup_steps": 4,
              "flops_warmup_steps": 8, "log_every": 5},
    "eval": {"batch_size_docs": 32, "batch_size_queries": 32, "recall_ks": [10, 100]},
}

# В этом блокноте обучаем только v2 (v1 — eval-only из готовых весов).
EXPERIMENTS = {
    "v2_splade_doc": {
        "model": {"query_encoder": "bow"},
        "train": {
                    "lambda_q": 0.0,      # запрос фиксирован, рег. не нужна
                    "lambda_d": 3e-4,     # рег. только на документы
                    "max_steps": 100_000
                },
    },
}

def build_config(name: str) -> dict:
    cfg = merge_config(BASE, EXPERIMENTS[name])
    if MODE == "smoke":
        cfg = merge_config(cfg, SMOKE_OVERRIDES)
    cfg["version"], cfg["mode"] = name, MODE
    return cfg

for name in EXPERIMENTS:
    print(f"=== {name} (mode={MODE}) ===")
    print(json.dumps(build_config(name), indent=2, ensure_ascii=False))
# Out:
# === v2_splade_doc (mode=full) ===
# {
#   "model": {
#     "hf_model": "distilbert-base-uncased",
#     "query_encoder": "bow",
#     "max_len_query": 32,
#     "max_len_doc": 256
#   },
#   "train": {
#     "seed": 4,
#     "lr": 2e-05,
#     "batch_size": 124,
#     "max_steps": 50000,
#     "warmup_steps": 6000,
#     "flops_warmup_steps": 10000,
#     "lambda_q": 0.0,
#     "lambda_d": 0.0003,
#     "log_every": 100
#   },
#   "eval": {
#     "batch_size_docs": 256,
#     "batch_size_queries": 64,
#     "batch_size_search": 64,
#     "recall_ks": [
#       10,
#       100,
#       1000
#     ]
#   },
#   "version": "v2_splade_doc",
#   "mode": "full"
# }

# %% [markdown]
# ## 4. Данные (переиспользуются)

# %%
from splade_lab import data as msdata

prepare = msdata.prepare_full if MODE == "full" else msdata.prepare_smoke
ds_dir = prepare(DATA)

print(f"\nКаталог: {ds_dir}")
print("Строк в файлах:", msdata.dataset_stats(ds_dir))
# Out:
# [data] full уже готов: /home/uvuv/workspace/sandbox_03/data/msmarco/full
#
# Каталог: /home/uvuv/workspace/sandbox_03/data/msmarco/full
# Строк в файлах: {'collection.tsv': 8841823, 'queries.tsv': 6980, 'qrels.tsv': 7437, 'triples.tsv': 3200000}

# %% [markdown]
# ## 5. v1 eval-only (инференс последней модели из outputs)
#
# Код инлайн — `splade_lab/` не меняем, поведение основного блокнота не затрагиваем.
#
# `find_latest_model_run` ищет в `outputs/<version>/` самый свежий прогон с сохранённой
# моделью (`run_id` = timestamp, поэтому максимум по имени = последний). `evaluate_only`
# грузит эти веса/токенайзер локально (без обращения к huggingface.co), прогоняет
# `evaluate.evaluate_retrieval` и пишет артефакты как обычный прогон (config/metrics/meta
# + `source_run`), чтобы строка попала в сводную таблицу `compare_runs()`.

# %%
# --- side-experiment: eval-only без train (код инлайн, splade_lab не меняем) ---
from transformers import AutoTokenizer

from splade_lab import artifacts, data, evaluate
from splade_lab.config import OUTPUTS_DIR
from splade_lab.model import Splade


def find_latest_model_run(version: str):
    """Последний прогон версии в outputs/<version>/ с сохранённой моделью (model/)."""
    base = OUTPUTS_DIR / version
    runs = [d for d in sorted(base.glob("*"))
            if d.is_dir() and (d / "model" / "config.json").exists()]
    if not runs:
        raise FileNotFoundError(f"Нет прогонов с сохранённой моделью в {base}")
    return runs[-1]  # run_id = timestamp YYYYMMDD-HHMMSS -> последний по имени = свежайший


def evaluate_only(version: str, data_cfg: dict, mode: str, recall_ks=None):
    """Только eval: берём последнюю модель из outputs/<version>/, train пропускаем.

    Артефакты пишутся как у обычного прогона (config/metrics/meta + ссылка на
    source_run), поэтому результат попадает в сводную таблицу compare_runs().
    """
    src_run = find_latest_model_run(version)
    model_dir = src_run / "model"

    # Конфиг исходной модели (для max_len/query_encoder/recall_ks).
    cfg = json.loads((src_run / "config.json").read_text(encoding="utf-8"))
    cfg["version"], cfg["mode"] = version, mode
    if recall_ks is not None:
        cfg["eval"]["recall_ks"] = recall_ks

    ds_dir = data.dataset_dir(data_cfg, mode)
    if not data.is_prepared(data_cfg, mode):
        raise RuntimeError(f"Данные не готовы: {ds_dir} "
                           f"(запустите клетку подготовки данных, mode={mode}).")

    device = pick_device()
    run_dir = artifacts.create_run_dir(version)
    artifacts.save_config(run_dir, cfg)
    meta = artifacts.start_meta(run_dir, cfg, device)
    meta["eval_only"] = True
    meta["source_run"] = src_run.name
    print(f"[eval-only] {version} mode={mode} device={device}")
    print(f"[eval-only] модель: {model_dir} -> {run_dir}")

    # Локальная загрузка обученных весов (from_pretrained по пути -> сети не нужно).
    tokenizer = AutoTokenizer.from_pretrained(str(model_dir))
    model = Splade(str(model_dir), cfg["model"]["query_encoder"]).to(device)

    metrics = evaluate.evaluate_retrieval(model, tokenizer, ds_dir, cfg, device)
    metrics["final_train_loss"] = None                   # train не запускался
    metrics["train_steps"] = cfg["train"]["max_steps"]   # шаги исходной модели (справочно)
    metrics["source_run"] = src_run.name
    artifacts.save_metrics(run_dir, metrics)
    artifacts.finish_meta(run_dir, meta)
    print(f"[eval-only] готово: {run_dir}")
    print(f"[eval-only] метрики: {metrics}")
    return run_dir, metrics

# %%
results = {}

# # v1 — БЕЗ train: только инференс последней модели из outputs/v1_splade_max/.
# run_dir, metrics = evaluate_only("v1_splade_max", DATA, MODE)
# results["v1_splade_max"] = {"run_dir": str(run_dir), **metrics}
# print(f"v1_splade_max (eval-only): mrr@10={metrics.get('mrr@10'):.4f} | {run_dir}")
# Out:
# [eval-only] v1_splade_max mode=full device=cuda
# [eval-only] модель: /home/uvuv/workspace/sandbox_03/outputs/v1_splade_max/20260613-005141/model -> /home/uvuv/workspace/sandbox_03/outputs/v1_splade_max/20260613-161423
# [progress] лог прогресса: /home/uvuv/workspace/sandbox_03/outputs/logs/progress_20260613-191424.log
# /home/uvuv/workspace/sandbox_03/splade_lab/evaluate.py:73: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at ../aten/src/ATen/SparseCsrTensorImpl.cpp:53.)
#   D = torch.sparse_csr_tensor(
# [eval-only] готово: /home/uvuv/workspace/sandbox_03/outputs/v1_splade_max/20260613-161423
# [eval-only] метрики: {'mrr@10': 0.32638593259653437, 'recall@10': 0.6040711556829035, 'recall@100': 0.8660100286532951, 'recall@1000': 0.9659264565425023, 'n_eval_queries': 6980, 'n_corpus_docs': 8841823, 'avg_nnz_doc': 198.071322622043, 'avg_nnz_query': 22.26704871060172, 'final_train_loss': None, 'train_steps': 100000, 'source_run': '20260613-005141'}
# v1_splade_max (eval-only): mrr@10=0.3264 | /home/uvuv/workspace/sandbox_03/outputs/v1_splade_max/20260613-161423

# %% [markdown]
# ## 6. v2 full (обучение + eval)
#
# v2 прогоняется полностью через штатный `run_experiment` (train -> save -> eval),
# как в основном блокноте.

# %%
from splade_lab.train import run_experiment

cfg = build_config("v2_splade_doc")
run_dir, metrics = run_experiment(cfg, DATA)
results["v2_splade_doc"] = {"run_dir": str(run_dir), **metrics}
print(f"v2_splade_doc (full): mrr@10={metrics.get('mrr@10'):.4f} | {run_dir}")

# %% [markdown]
# ## 7. Сравнение версий (все прогоны из outputs/)

# %%
from splade_lab.compare import compare_runs

df = compare_runs()  # печатает таблицу и пишет outputs/comparison.csv
df

# %% [markdown]
# ## Примечания
#
# - Это **side-experiment**: вся новая логика (eval-only) живёт в клетке 5 этого
#   блокнота, `splade_lab/` и основной блокнот не изменены.
# - v1 НЕ обучается — `evaluate_only("v1_splade_max", ...)` берёт **последнюю** по
#   timestamp модель из `outputs/v1_splade_max/` и делает только инференс/eval.
# - Чтобы переоценить конкретный прогон v1 (не последний), временно убери лишние
#   каталоги из `outputs/v1_splade_max/` или поправь `find_latest_model_run`.
# - eval-only прогон пишется в новый `outputs/v1_splade_max/<run_id>/` с пометкой
#   `eval_only` и ссылкой `source_run` в `meta.json`.
